# %%
import torch
from pan.networks import PAN
from torchinfo import summary

# %%
model = PAN(backbone='resnet34', pretrained=True, n_class=2)
model_file = torch.load('./model file/PAN(using train cropped, val rescaled)).pth')
model.load_state_dict(model_file)
model.eval()

summary(model)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18012\3118528976.py in <module>
#       1 model = PAN(backbone='resnet34', pretrained=True, n_class=2)
#       2 model_file = torch.load('./model file/PAN(using train cropped, val rescaled)).pth')
# ----> 3 model.load_state_dict(model_file)
#       4 model.eval()
#       5
#
# ~\anaconda3\envs\deep_learning\lib\site-packages\torch\nn\modules\module.py in load_state_dict(self, state_dict, strict)
#    1426         if len(error_msgs) > 0:
#    1427             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# -> 1428                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    1429         return _IncompatibleKeys(missing_keys, unexpected_keys)
#    1430
#
# RuntimeError: Error(s) in loading state_dict for PAN:
# ...
